# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
df = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
df.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(data = df, x = 'gender', y = 'age', hue = 'manner_of_death')
plt.legend(loc = (0));

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(12,6), dpi = 150)
sns.swarmplot(data = df, x = 'gender', y = 'age', hue = 'manner_of_death');

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = df.city.value_counts()[:12]
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = df.state.value_counts()[:20] # mds = shorteness of most dangerous state
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = df.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.barplot(x = illness.index, y = illness.values)

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = df.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
threads_freq.plot.bar()
plt.xticks(rotation=60)
for index , value in enumerate(threads_freq.values):
    plt.text(index, value+0.1, str(value), ha = 'center')

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = df.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn
sns.barplot(flee_freq.index, y = flee_freq.values)
