# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd
import numpy as np

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode  ...         Country  Total
# 0    536365    85123A  ...  United Kingdom  15.30
# 1    536365     71053  ...  United Kingdom  20.34
# 2    536365    84406B  ...  United Kingdom  22.00
# 3    536365    84029G  ...  United Kingdom  20.34
# 4    536365    84029E  ...  United Kingdom  20.34
#
# [5 rows x 9 columns]

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ** Show the statistical measurements of ecom dataset **

# %%
ecom.describe().T
# Out:
#                count          mean          std  ...       50%       75%      max
# Quantity    541909.0      9.552250   218.081158  ...      3.00     10.00  80995.0
# UnitPrice   541909.0      4.611114    96.759853  ...      2.08      4.13  38970.0
# CustomerID  406829.0  15287.690570  1713.600303  ...  15152.00  16791.00  18287.0
#
# [3 rows x 8 columns]

# %% [markdown]
# ** What is the average Purchase Price? **
# **Ortalama satın alma fiyatı nedir?**

# %%
ecom.UnitPrice.mean()
# Out:
# 4.611113626083471

# %% [markdown]
# ** What were the highest and lowest purchase prices? **
# **Maksimum ve minimum satın alma fiyatları nelerdir?**

# %%
ecom.UnitPrice.max()
# Out:
# 38970.0

# %%
ecom.UnitPrice.min()
# Out:
# -11062.06

# %% [markdown]
# ** List the country names and number of records belongs to each country **
# **Ülke adlarını, her ülke adına kaç kayıt olduğu şekliyle listeleyiniz**

# %%
ecom["Country"].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ** How many records are as Country United Kingdom? ** **United Kingdom'a ait kaç kayıt vardır**

# %%
ecom[ecom["Country"] == "United Kingdom"].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ** Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ? **
# **"UnitPrice" ve "Quantity" kullanarak toplam harcama miktarını gösteren "Total" adlı bir sütun oluşturun.**

# %%
ecom["Total"] = ecom["UnitPrice"]*ecom["Quantity"]
ecom["Total"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %% [markdown]
# ** Show total spending amount according to the Countries **
# **ülkelere göre toplam harcama miktarlarını gösterinin**

# %%
ecom.groupby("Country")["Total"].sum()/1000
# Out:
# Country
# Australia                137.077270
# Austria                   10.154320
# Bahrain                    0.548400
# Belgium                   40.910960
# Brazil                     1.143600
# Canada                     3.666380
# Channel Islands           20.086290
# Cyprus                    12.946290
# Czech Republic             0.707720
# Denmark                   18.768140
# EIRE                     263.276820
# European Community         1.291750
# Finland                   22.326740
# France                   197.403900
# Germany                  221.698210
# Greece                     4.710520
# Hong Kong                 10.117040
# Iceland                    4.310000
# Israel                     7.907820
# Italy                     16.890510
# Japan                     35.340620
# Lebanon                    1.693880
# Lithuania                  1.661060
# Malta                      2.505470
# Netherlands              284.661540
# Norway                    35.163460
# Poland                     7.213140
# Portugal                  29.367020
# RSA                        1.002310
# Saudi Arabia               0.131170
# Singapore                  9.120390
# Spain                     54.774580
# Sweden                    36.595910
# Switzerland               56.385350
# USA                        1.730920
# United Arab Emirates       1.902280
# United Kingdom          8187.806364
# Unspecified                4.749790
# Name: Total, dtype: float64

# %% [markdown]
# ** Which Country spend least? ** **En az harcama yapan ülke hangisidir?**

# %%
ecom.groupby("Country")["Total"].sum().sort_values()
# Out:
# Country
# Saudi Arabia            1.311700e+02
# Bahrain                 5.484000e+02
# Czech Republic          7.077200e+02
# RSA                     1.002310e+03
# Brazil                  1.143600e+03
# European Community      1.291750e+03
# Lithuania               1.661060e+03
# Lebanon                 1.693880e+03
# USA                     1.730920e+03
# United Arab Emirates    1.902280e+03
# Malta                   2.505470e+03
# Canada                  3.666380e+03
# Iceland                 4.310000e+03
# Greece                  4.710520e+03
# Unspecified             4.749790e+03
# Poland                  7.213140e+03
# Israel                  7.907820e+03
# Singapore               9.120390e+03
# Hong Kong               1.011704e+04
# Austria                 1.015432e+04
# Cyprus                  1.294629e+04
# Italy                   1.689051e+04
# Denmark                 1.876814e+04
# Channel Islands         2.008629e+04
# Finland                 2.232674e+04
# Portugal                2.936702e+04
# Norway                  3.516346e+04
# Japan                   3.534062e+04
# Sweden                  3.659591e+04
# Belgium                 4.091096e+04
# Spain                   5.477458e+04
# Switzerland             5.638535e+04
# Australia               1.370773e+05
# France                  1.974039e+05
# Germany                 2.216982e+05
# EIRE                    2.632768e+05
# Netherlands             2.846615e+05
# United Kingdom          8.187806e+06
# Name: Total, dtype: float64

# %%
ecom.groupby("Country")["Total"].sum().sort_values()[:1]
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average of spending according to country with apply function? **
# **.apply function kullanarak ülkelerin ortalama harcamasını hesaplayınız.**

# %%
ecom.groupby("Country")["Total"].apply(np.mean)
# ecom.groupby('Country')['Total'].apply(lambda x : x.mean())
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average,min,max of spending according to country with agg function? **
# **agg Function kullanarak, Ülkelerin Ortalama, min ve max harcamalarını hesaplayınız**

# %%
ecom.groupby("Country")["Total"].agg(["mean", "min", "max"])
# Out:
#                             mean        min        max
# Country
# Australia             108.877895    -425.00    1718.40
# Austria                25.322494     -21.25     360.00
# Bahrain                28.863158    -205.74     205.74
# Belgium                19.773301     -19.95     165.00
# Brazil                 35.737500      15.00     175.20
# Canada                 24.280662       2.50     550.94
# Channel Islands        26.499063    -293.00     408.00
# Cyprus                 20.813971    -320.69     320.69
# Czech Republic         23.590667     -35.76      70.80
# Denmark                48.247147     -59.80     428.40
# EIRE                   32.122599   -1917.00    2365.20
# European Community     21.176230      -8.50      60.00
# Finland                32.124806     -80.00     551.20
# France                 23.069288   -8322.12    4161.06
# Germany                23.348943    -599.50     876.00
# Greece                 32.263836     -50.00     175.20
# Hong Kong              35.128611   -2653.95    2653.95
# Iceland                23.681319       5.04     249.60
# Israel                 26.625657    -136.00     350.40
# Italy                  21.034259     -89.55     300.00
# Japan                  98.716816   -1591.20    3794.40
# Lebanon                37.641778      10.20     153.00
# Lithuania              47.458857      13.20     122.40
# Malta                  19.728110    -130.00     455.00
# Netherlands           120.059696    -266.40    4992.00
# Norway                 32.378877    -376.50     700.00
# Poland                 21.152903     -39.80     120.00
# Portugal               19.333127   -1241.98    1241.98
# RSA                    17.281207       0.00      38.25
# Saudi Arabia           13.117000     -14.75      19.80
# Singapore              39.827031   -3949.32    3949.32
# Spain                  21.624390   -1715.85    1350.00
# Sweden                 79.211926   -1188.00    1188.00
# Switzerland            28.164510    -179.00     360.00
# USA                     5.948179     -74.88      81.36
# United Arab Emirates   27.974706       3.48     153.00
# United Kingdom         16.525065 -168469.60  168469.60
# Unspecified            10.649753       0.19      69.36

# %% [markdown]
# ** What is the max Total spending in whole dataset and show the records of that spending ?**
# **Tüm DAtasetteki En çok toplam harcamanın kayıdını gösteriniz**

# %%
ecom[ecom["Total"]==ecom["Total"].max()]
# Out:
#        InvoiceNo StockCode  ...         Country     Total
# 540421    581483     23843  ...  United Kingdom  168469.6
#
# [1 rows x 9 columns]

# %% [markdown]
# ** How many people who live in Spain spend more than average Total ?**
# **ispanyada yaşayan insanlardan, ortalama harcamanın üzerinde harcama yapmış kaç kişi vardır?

# %%
ecom[(ecom["Total"] > ecom["Total"].mean()) & (ecom["Country"] == "Spain")].count()
# Out:
# InvoiceNo      728
# StockCode      728
# Description    728
# Quantity       728
# InvoiceDate    728
# UnitPrice      728
# CustomerID     728
# Country        728
# Total          728
# dtype: int64

# %% [markdown]
# ** Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**
# **InvoiceDate sütununu datetime'a çevirerek, InvaciDate2 isminde yani bir sütun oluşturunuz**

# %%
ecom['InvoiceDate2']=pd.to_datetime(ecom.InvoiceDate)
ecom['InvoiceDate2']
# Out:
# 0       2010-12-01 08:26:00
# 1       2010-12-01 08:26:00
# 2       2010-12-01 08:26:00
# 3       2010-12-01 08:26:00
# 4       2010-12-01 08:26:00
#                 ...
# 37304   2010-12-17 17:23:00
# 37305   2010-12-17 17:23:00
# 37306   2010-12-17 17:23:00
# 37307   2010-12-17 17:23:00
# 37308   2020-12-17 00:00:00
# Name: InvoiceDate2, Length: 37309, dtype: datetime64[ns]

# %% [markdown]
# ** Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date **
# **Oluşturduğumuz InvoiceDate2 sütunundaki verileri (Yıl-Ay-Gün)formatına çevirip oluşturacağımız "date" ismindeki sütuna atayalım.**

# %%
ecom["Date"] = pd.to_datetime(ecom.InvoiceDate2.dt.date)
ecom["Date"]
# Out:
# 0       2010-12-01
# 1       2010-12-01
# 2       2010-12-01
# 3       2010-12-01
# 4       2010-12-01
#            ...
# 37304   2010-12-17
# 37305   2010-12-17
# 37306   2010-12-17
# 37307   2010-12-17
# 37308   2020-12-17
# Name: Date, Length: 37309, dtype: datetime64[ns]

# %% [markdown]
# ** drop InvoiceDate2 and InvoiceDate columns permanently **
# **InvoiceDate2 and InvoiceDate sütunlarını KALICI olarak silelim.**

# %%
ecom.drop(["InvoiceDate","InvoiceDate2"], axis=1, inplace=True)
ecom.head()
# Out:
#   InvoiceNo StockCode  ...  Total       Date
# 0    536365    85123A  ...  15.30 2010-12-01
# 1    536365     71053  ...  20.34 2010-12-01
# 2    536365    84406B  ...  22.00 2010-12-01
# 3    536365    84029G  ...  20.34 2010-12-01
# 4    536365    84029E  ...  20.34 2010-12-01
#
# [5 rows x 9 columns]

# %% [markdown]
# ** Remove A, B, G and E from StockCode in first 5 rows of ecom dataframe with a string method **
# **string metod ile ilk 5 sütundaki A, B, G ve E'yi kaldıralım**

# %%
ecom.StockCode[:5].str.replace('A','').str.replace('B','').str.replace('G','').str.replace('E','')
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %% [markdown]
# ** take only Total and date columns with loc and craete a new df named ecom2 **
# **ecom2 isminde, sadece Total ve date sütunları olan bir dataframei .LOC İLE oluşturunuz**

# %%
ecom2 = ecom.loc[:,["Total","Date"]]
ecom2
# Out:
#        Total       Date
# 0      15.30 2010-12-01
# 1      20.34 2010-12-01
# 2      22.00 2010-12-01
# 3      20.34 2010-12-01
# 4      20.34 2010-12-01
# ...      ...        ...
# 37304  15.90 2010-12-17
# 37305   1.25 2010-12-17
# 37306   5.95 2010-12-17
# 37307   5.95 2010-12-17
# 37308    NaN 2020-12-17
#
# [37309 rows x 2 columns]

# %% [markdown]
# ** take only InvoiceNo, CustomerID and Total columns with iloc and craete a new df named ecom3 **
# **ecom3 isminde, sadece InvoiceNo, CustomerID ve Total sütunları olan bir dataframei .ILOC İLE oluşturunuz**

# %%
ecom3 = ecom.iloc[:,[0,5,7]]
ecom3
# Out:
#        InvoiceNo  UnitPrice         Country
# 0         536365       2.55  United Kingdom
# 1         536365       3.39  United Kingdom
# 2         536365       2.75  United Kingdom
# 3         536365       3.39  United Kingdom
# 4         536365       3.39  United Kingdom
# ...          ...        ...             ...
# 541904    581587       0.85          France
# 541905    581587       2.10          France
# 541906    581587       4.15          France
# 541907    581587       4.15          France
# 541908    581587       4.95          France
#
# [541909 rows x 3 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with concat **
# **.concat ile birleştiriniz**

# %%
ecom_concat2_3= pd.concat([ecom2, ecom3], axis=1)
ecom_concat2_3
# Out:
#         Total       Date InvoiceNo  UnitPrice         Country
# 0       15.30 2010-12-01    536365       2.55  United Kingdom
# 1       20.34 2010-12-01    536365       3.39  United Kingdom
# 2       22.00 2010-12-01    536365       2.75  United Kingdom
# 3       20.34 2010-12-01    536365       3.39  United Kingdom
# 4       20.34 2010-12-01    536365       3.39  United Kingdom
# ...       ...        ...       ...        ...             ...
# 541904    NaN        NaT    581587       0.85          France
# 541905    NaN        NaT    581587       2.10          France
# 541906    NaN        NaT    581587       4.15          France
# 541907    NaN        NaT    581587       4.15          France
# 541908    NaN        NaT    581587       4.95          France
#
# [541909 rows x 5 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with merge. If memory error occurs take only first 400 rows from both DFs.**
# **merge ile birleştiriniz. Memory problemi olur ise sadece ilk 400 satır ile yapınız**.

# %%
ecom_merge_2_3 = pd.merge(ecom2.iloc[:400,:],ecom3.iloc[:400,:], on='Total', left_index=True , right_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-d741190e7fe5> in <module>()
# ----> 1 ecom_merge_2_3 = pd.merge(ecom2.iloc[:400,:],ecom3.iloc[:400,:], on='Total', left_index=True , right_index=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'Total'

# %% [markdown]
# ** Combine ecom2 and ecom3 with join (inner)**

# %%
join_ecom2_3 = ecom2.join(ecom3, how="inner",lsuffix='_left',rsuffix='_right')
join_ecom2_3
# Out:
#        Total       Date InvoiceNo  UnitPrice         Country
# 0      15.30 2010-12-01    536365       2.55  United Kingdom
# 1      20.34 2010-12-01    536365       3.39  United Kingdom
# 2      22.00 2010-12-01    536365       2.75  United Kingdom
# 3      20.34 2010-12-01    536365       3.39  United Kingdom
# 4      20.34 2010-12-01    536365       3.39  United Kingdom
# ...      ...        ...       ...        ...             ...
# 37304  15.90 2010-12-17    539456       7.95  United Kingdom
# 37305   1.25 2010-12-17    539456       1.25  United Kingdom
# 37306   5.95 2010-12-17    539456       5.95  United Kingdom
# 37307   5.95 2010-12-17    539456       5.95  United Kingdom
# 37308    NaN 2020-12-17    539456       7.95  United Kingdom
#
# [37309 rows x 5 columns]

# %% [markdown]
# # Congrats!
